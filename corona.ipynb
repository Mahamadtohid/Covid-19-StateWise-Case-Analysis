# %%
# %pip install pandas
# %pip install seaborn
# %pip install matplotlib.pyplot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000153E107FD10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/matplotlib-pyplot/
# ...

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt 

#df = pd.read_csv('corona.csv')

# %%
columns = [
    "sno", "state_name", "active", "positive", "cured", "death", "new_active", 
    "new_positive", "new_cured", "new_death", "state_code" , "extra_column"
]

# Manually organizing the data into rows based on visual inspection
data_rows = [
    [1, "Andaman and Nicobar Islands", 23, 4960, 4875, 62, 17, 4963, 4884, 62, 35],
    [2, "Andhra Pradesh", 2544, 884916, 875243, 7129, 2450, 885037, 875456, 7131, 28],
    [3, "Arunachal Pradesh", 66, 16772, 16650, 56, 6, 16777, 16658, 56, 12],
    [4, "Assam", 3041, 216590, 212515, 1061, 2092, 216635, 212579, 1064, 18],
    [5, "Bihar", 4178, 255700, 250088, 1434, 4054, 255932, 250439, 1439, 10],
    [6, "Chandigarh", 241, 20295, 19727, 327, 259, 20342, 19756, 327, 4],
    [7, "Chhattisgarh", 8967, 289231, 276714, 3409, 8550, 290084, 278029, 3490, 22],
    [8, "Dadra and Nagar Haveli and Daman and Diu", 2, 3380, 3376, 4, 2, 3382, 3376, 2, 26],
    [9, "Delhi", 3486, 630000, 616054, 10678, 3354, 620506, 616461, 3354, 7],
    [10, "Goa", 832, 51856, 50277, 747, 799, 51891, 50304, 799, 30],
    [11, "Gujarat", 7829, 251494, 239771, 5465, 7695, 252559, 240517, 7695, 24],
    [12, "Haryana", 971, 54521, 259495, 2950, 2587, 56521, 259875, 2955, 6],
    [13, "Himachal Pradesh", 1971, 56452, 54522, 959, 874, 56521, 54566, 961, 2],
    [14, "Jammu and Kashmir", 2011, 122538, 118617, 1910, 1768, 122651, 118972, 1911, 1],
    [15, "Jharkhand", 1468, 116817, 114302, 1432, 1087, 116961, 114531, 1382, 20],
    [16, "Karnataka", 9668, 927559, 905751, 12140, 9363, 928055, 906548, 12144, 29],
    [17, "Kerala", 64379, 811134, 743467, 3302, 63547, 814258, 747389, 3380, 32],
    [18, "Ladakh", 197, 9618, 9118, 127, 37, 9621, 9119, 127, 37],
    [19, "Lakshadweep", 0, 0, 0, 0, 0, 0, 0, 0, 0, 31],
    [20, "Madhya Pradesh", 7823, 248597, 237063, 3711, 7651, 249082, 237733, 3718, 23],
    [21, "Maharashtra", 55351, 1969114, 1863702, 50061, 53463, 1971552, 1867988, 50101, 27],
    [22, "Manipur", 490, 28660, 27805, 365, 477, 28693, 27851, 365, 14],
    [23, "Meghalaya", 155, 13611, 13313, 143, 151, 13631, 13337, 143, 17],
    [24, "Mizoram", 92, 4293, 4192, 9, 96, 4299, 4194, 9, 15],
    [25, "Nagaland", 116, 11978, 11783, 84, 108, 11987, 11795, 84, 13],
    [26, "Odisha", 1298, 331862, 328043, 1891, 1943, 332106, 328271, 1897, 21],
    [27, "Puducherry", 316, 38455, 37501, 638, 304, 38477, 37535, 638, 34],
    [28, "Punjab", 2903, 169033, 160655, 5445, 2858, 169225, 160920, 5447, 3],
    [29, "Rajasthan", 6726, 312996, 303536, 2734, 6585, 313425, 304104, 2734, 8],
    [30, "Sikkim", 351, 5988, 5508, 129, 322, 5989, 5538, 129, 11],
    [31, "Tamil Nadu", 71654, 826261, 806875, 12222, 6971, 826943, 807444, 12222, 33],
    [32, "Telangana", 4518, 290008, 283924, 1566, 4524, 290309, 284217, 1568, 36],
    [33, "Tripura", 530, 33869, 32869, 388, 479, 33872, 32872, 388, 16],
    [34, "Uttarakhand", 3134, 93621, 89181, 1578, 1573, 93680, 89346, 1578, 5],
    [35, "Uttar Pradesh", 11134, 593171, 573542, 8495, 10864, 593680, 574312, 8504, 9],
    [36, "West Bengal", 12878, 510709, 542887, 9941, 7538, 512381, 543826, 9957, 19]
]
df = pd.DataFrame(data_rows , columns=columns)

# %%
df
df.drop("extra_column" , axis=1 , inplace=True)
df_reset = df.reset_index(drop=True)

df_reset
df.shape
df.isnull().sum()
# Out:
# sno              0
# state_name       0
# active           0
# positive         0
# cured            0
# death            0
# new_active       0
# new_positive     0
# new_cured        0
# new_death        0
# state_code       0
# extra_column    35
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sno           36 non-null     int64
#  1   state_name    36 non-null     object
#  2   active        36 non-null     int64
#  3   positive      36 non-null     int64
#  4   cured         36 non-null     int64
#  5   death         36 non-null     int64
#  6   new_active    36 non-null     int64
#  7   new_positive  36 non-null     int64
#  8   new_cured     36 non-null     int64
#  9   new_death     36 non-null     int64
#  10  state_code    36 non-null     int64
#  11  extra_column  1 non-null      float64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 3.5+ KB

# %%
df.describe()
# Out:
#              sno        active      positive         cured         death  \
# count  36.000000     36.000000  3.600000e+01  3.600000e+01     36.000000
# mean   18.500000   8092.861111  2.835016e+05  2.803595e+05   4238.666667
# std    10.535654  17496.602727  4.025043e+05  3.837272e+05   8658.000809
# min     1.000000      0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%     9.750000    297.250000  1.941425e+04  1.895775e+04    281.000000
# 50%    18.500000   1991.000000  1.196775e+05  1.396360e+05   1500.000000
# 75%    27.250000   7000.250000  3.177125e+05  3.096628e+05   4144.500000
# max    36.000000  71654.000000  1.969114e+06  1.863702e+06  50061.000000
#
#          new_active  new_positive     new_cured     new_death  state_code  \
# count     36.000000  3.600000e+01  3.600000e+01     36.000000   36.000000
# mean    5956.888889  2.836674e+05  2.808539e+05   4104.472222   17.972222
# std    13363.607355  4.027313e+05  3.844609e+05   8612.781640   11.162401
# ...

# %%
df.tail()
# Out:
#     sno     state_name  active  positive   cured  death  new_active  \
# 31   32      Telangana    4518    290008  283924   1566        4524
# 32   33        Tripura     530     33869   32869    388         479
# 33   34    Uttarakhand    3134     93621   89181   1578        1573
# 34   35  Uttar Pradesh   11134    593171  573542   8495       10864
# 35   36    West Bengal   12878    510709  542887   9941        7538
#
#     new_positive  new_cured  new_death  state_code  extra_column
# 31        290309     284217       1568          36           NaN
# 32         33872      32872        388          16           NaN
# 33         93680      89346       1578           5           NaN
# 34        593680     574312       8504           9           NaN
# 35        512381     543826       9957          19           NaN

# %%
df=df.iloc[:36]

# %%
df
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Islands      23      4960     4875
# 1     2                            Andhra Pradesh    2544    884916   875243
# 2     3                         Arunachal Pradesh      66     16772    16650
# 3     4                                     Assam    3041    216590   212515
# 4     5                                     Bihar    4178    255700   250088
# 5     6                                Chandigarh     241     20295    19727
# 6     7                              Chhattisgarh    8967    289231   276714
# 7     8  Dadra and Nagar Haveli and Daman and Diu       2      3380     3376
# 8     9                                     Delhi    3486    630000   616054
# 9    10                                       Goa     832     51856    50277
# 10   11                                   Gujarat    7829    251494   239771
# ...

# %%
df['active'].sum(axis = 0)
# Out:
# np.int64(291343)

# %%
df['positive'].sum(axis = 0)
# Out:
# np.int64(10206059)

# %%
df['cured'].sum(axis = 0)
# Out:
# np.int64(10092941)

# %%
df['death'].sum(axis = 0)
# Out:
# np.int64(152592)

# %%
df['new_active'].sum(axis = 0)
# Out:
# np.int64(214448)

# %%
df['new_positive'].sum(axis = 0)
# Out:
# np.int64(10212027)

# %%
sns.pairplot(data=df)

# %%
cases_df=df.sum()

# %%
cases_df
# Out:
# sno                                                           666
# state_name      Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                     291343
# positive                                                 10206059
# cured                                                    10092941
# death                                                      152592
# new_active                                                 214448
# new_positive                                             10212027
# new_cured                                                10110742
# new_death                                                  147761
# state_code                                                    647
# extra_column                                                 31.0
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)

# %%
cases_df.drop(['extra_column'],inplace=True)

# %%
cases_df
# Out:
# active            291343
# positive        10206059
# cured           10092941
# death             152592
# new_active        214448
# new_positive    10212027
# new_cured       10110742
# new_death         147761
# dtype: object

# %%
df
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Islands      23      4960     4875
# 1     2                            Andhra Pradesh    2544    884916   875243
# 2     3                         Arunachal Pradesh      66     16772    16650
# 3     4                                     Assam    3041    216590   212515
# 4     5                                     Bihar    4178    255700   250088
# 5     6                                Chandigarh     241     20295    19727
# 6     7                              Chhattisgarh    8967    289231   276714
# 7     8  Dadra and Nagar Haveli and Daman and Diu       2      3380     3376
# 8     9                                     Delhi    3486    630000   616054
# 9    10                                       Goa     832     51856    50277
# 10   11                                   Gujarat    7829    251494   239771
# ...

# %%
my_data = [222526,10466595,10092909,151160]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()

# %%
my_data = [216558,10479179,10111294,151327]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()

# %%
my_data = [222526,10466595,10092909,151160,216558,10479179,10111294,151327]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()

# %%
plt.rcParams['figure.figsize']=(13,8)

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code',
#        'extra_column'],
#       dtype='object')

# %%
df.drop(['sno','state_code','extra_column'],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#                     state_name  active  positive   cured  death  new_active  \
# 0  Andaman and Nicobar Islands      23      4960    4875     62          17
# 1               Andhra Pradesh    2544    884916  875243   7129        2450
# 2            Arunachal Pradesh      66     16772   16650     56           6
# 3                        Assam    3041    216590  212515   1061        2092
# 4                        Bihar    4178    255700  250088   1434        4054
#
#    new_positive  new_cured  new_death
# 0          4963       4884         62
# 1        885037     875456       7131
# 2         16777      16658         56
# 3        216635     212579       1064
# 4        255932     250439       1439

# %%
df=df.set_index('state_name')

# %%
df.head(5)
# Out:
#                              active  positive   cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands      23      4960    4875     62          17
# Andhra Pradesh                 2544    884916  875243   7129        2450
# Arunachal Pradesh                66     16772   16650     56           6
# Assam                          3041    216590  212515   1061        2092
# Bihar                          4178    255700  250088   1434        4054
#
#                              new_positive  new_cured  new_death
# state_name
# Andaman and Nicobar Islands          4963       4884         62
# Andhra Pradesh                     885037     875456       7131
# Arunachal Pradesh                   16777      16658         56
# Assam                              216635     212579       1064
# Bihar                              255932     250439       1439

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Out:
# <Axes: ylabel='state_name'>

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# Out:
# <Axes: ylabel='state_name'>

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# Out:
# <Axes: ylabel='state_name'>

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases
# Out:
# <Axes: ylabel='state_name'>

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
# Out:
# <Axes: ylabel='state_name'>
